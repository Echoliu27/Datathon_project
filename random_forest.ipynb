# %%
import pandas as pd
import numpy as np

# %%
cluster = pd.read_csv('~/Downloads/user_categorical_w_cluster.csv')
# Out:
# /anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
x = cluster.drop(['user_id','user_signup_timestamp','zipcode','recent_bankruptcy_date','Unnamed..0'],1)
x
# Out:
#        state  is_homeowner  gender    age_bucket credit_score_bucket  cluster
# 0         AR          True  Female  (45.0, 50.0]      (630.0, 635.0]        2
# 1         NE         False     NaN  (50.0, 55.0]      (575.0, 580.0]        2
# 2         AL         False    Male  (50.0, 55.0]      (685.0, 690.0]        2
# 3         MT          True  Unisex  (50.0, 55.0]      (625.0, 630.0]        1
# 4         PA         False  Female  (20.0, 25.0]      (630.0, 635.0]        4
# 5         NC         False  Female  (35.0, 40.0]      (670.0, 675.0]        2
# 6         FL         False  Female  (45.0, 50.0]      (570.0, 575.0]        2
# 7         UT         False    Male  (35.0, 40.0]      (545.0, 550.0]        4
# 8         TN         False  Female  (30.0, 35.0]      (650.0, 655.0]        4
# 9         MS          True     NaN  (45.0, 50.0]      (535.0, 540.0]        2
# 10        KY         False  Female  (45.0, 50.0]      (770.0, 775.0]        4
# ...

# %%
#sample
df_sample = x.sample(frac = 0.1, replace = False)
df_sample
# Out:
#        state  is_homeowner  gender    age_bucket credit_score_bucket  cluster
# 43337     TX         False  Unisex  (20.0, 25.0]      (510.0, 515.0]        2
# 211106    FL          True  Unisex  (40.0, 45.0]      (710.0, 715.0]        4
# 162065    GA          True    Male  (50.0, 55.0]      (615.0, 620.0]        1
# 4689      MD         False  Female  (25.0, 30.0]      (515.0, 520.0]        2
# 50043     TX          True  Female  (60.0, 65.0]      (635.0, 640.0]        1
# 75209     RI         False    Male  (70.0, 75.0]      (530.0, 535.0]        2
# 201652    NJ          True  Unisex  (55.0, 60.0]      (585.0, 590.0]        1
# 176761    MD         False  Unisex  (40.0, 45.0]      (515.0, 520.0]        2
# 122721    IA         False  Female  (30.0, 35.0]      (520.0, 525.0]        2
# 180649    TN         False  Female  (45.0, 50.0]      (500.0, 505.0]        2
# 115058    OH          True    Male  (45.0, 50.0]      (515.0, 520.0]        2
# ...

# %%
#split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(df_sample.drop('cluster',1),list(df_sample['cluster']),test_size=0.3,random_state=8)

# %%
x_train=pd.get_dummies(x_train,drop_first=True)
x_test=pd.get_dummies(x_test,drop_first=True)
y_train=pd.get_dummies(y_train,drop_first=False)
y_test=pd.get_dummies(y_test,drop_first=False)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

para ={'n_estimators':[50,100,150,200]}
gsearchRandom = GridSearchCV(estimator = RandomForestClassifier(random_state=42),param_grid = para,cv=5)
gsearchRandom.fit(x_train, y_train)
pred=gsearchRandom.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-b913b687aed1> in <module>()
#       5 gsearchRandom = GridSearchCV(estimator = RandomForestClassifier(random_state=42),param_grid = para,cv=5)
#       6 gsearchRandom.fit(x_train, y_train)
# ----> 7 pred=gsearchRandom.predict(x_test)
#
# /anaconda/lib/python3.6/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#      52
#      53         # lambda, but not partial, allows help() to work with update_wrapper
# ---> 54         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#      55         # update the docstring of the returned function
#      56         update_wrapper(out, self.fn)
#
# /anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py in predict(self, X)
#     446         """
#     447         self._check_is_fitted('predict')
# ...
